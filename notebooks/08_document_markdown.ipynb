# %% [markdown]
# <div align="center">
# <p align="center" style="width: 100%;">
#     <img src="https://raw.githubusercontent.com/vlm-run/.github/refs/heads/main/profile/assets/vlm-black.svg" alt="VLM Run Logo" width="80" style="margin-bottom: -5px; color: #2e3138; vertical-align: middle; padding-right: 5px;"><br>
# </p>
# <p align="center"><a href="https://docs.vlm.run"><b>Website</b></a> | <a href="https://docs.vlm.run/"><b>API Docs</b></a> | <a href="https://docs.vlm.run/blog"><b>Blog</b></a> | <a href="https://discord.gg/AMApC2UzVY"><b>Discord</b></a>
# </p>
# <p align="center">
# <a href="https://discord.gg/AMApC2UzVY"><img alt="Discord" src="https://img.shields.io/badge/discord-chat-purple?color=%235765F2&label=discord&logo=discord"></a>
# <a href="https://twitter.com/vlmrun"><img alt="Twitter Follow" src="https://img.shields.io/twitter/follow/vlmrun.svg?style=social&logo=twitter"></a>
# </p>
# </div>
#
# Welcome to **[VLM Run Cookbooks](https://github.com/vlm-run/vlmrun-cookbook)**, a comprehensive collection of examples and notebooks demonstrating the power of structured visual understanding using the [VLM Run Platform](https://app.vlm.run).

# %% [markdown]
# ## Case Study: Document Markdown Extraction
#
# The `document.markdown` domain is designed to convert document pages into structured markdown content with rich formatting, tables, and figures. This cookbook provides examples of how to use the domain through the VLM client.

# %% [markdown]
# ### Response Model
#
# The `document.markdown` domain returns a structured `MarkdownDocument` object that provides comprehensive access to document content, tables, and figures with advanced processing capabilities.
#
# ```python
# # Main response object
# class MarkdownDocument:
#     pages: List[MarkdownPage]
#
#     # Properties
#     @property
#     def content(self) -> str  # Combined content from all pages
#     @property
#     def markdown_content(self) -> str  # Combined rendered markdown
#     @property
#     def tables(self) -> List[MarkdownTable]  # All tables across pages
#     @property
#     def figures(self) -> List[MarkdownFigure]  # All figures across pages
#
#     # Methods
#     def get_page(self, page_number: int) -> MarkdownPage
#     def render(self) -> str  # Full document rendering
# ```
#
# ### MarkdownPage Structure
# Each page in the document contains structured content with optional tables and figures:
#
# ```python
# class MarkdownPage:
#     content: str  # Raw markdown content with placeholders
#     markdown_content: str  # Rendered markdown content
#     tables: Optional[List[MarkdownTable]] = None
#     figures: Optional[List[MarkdownFigure]] = None
#     page_number: Optional[int] = None  # 0-indexed page number
#
#     # Methods
#     def render(self) -> str  # Page-specific rendering
# ```
#
# ### Key Features
# - **Structured Document**: Complete `MarkdownDocument` object with pages, tables, and figures
# - **Page Numbers**: Optional 0-indexed page numbering for multi-page documents
# - **Rich Tables**: Full pandas DataFrame conversion, rendering, and data manipulation
# - **Figures**: Image descriptions and captions (can be None)
#
# ### Table Structure
# Tables are extracted as structured `MarkdownTable` objects with rich functionality:
#
# ```python
# class MarkdownTable:
#     metadata: TableMetadata
#     headers: List[TableHeader]
#     data: List[List[TableCell]]
#     bbox: Optional[BoxCoords] = None
#
#     # Methods
#     def to_dataframe(self) -> 'pandas.DataFrame'
#     def render(self) -> str  # HTML table rendering
#     def validate(self) -> bool  # Data validation
#     def get_column_data(self, column_name: str) -> List[Any]
#     def filter_rows(self, condition: callable) -> 'MarkdownTable'
#
# class TableMetadata:
#     title: Optional[str] = None
#     caption: Optional[str] = None
#     notes: Optional[str] = None
#
# class TableHeader:
#     id: str
#     column: int
#     name: str
#     dtype: str  # 'string', 'number', 'date', etc.
#
# class TableCell:
#     content: Any
#     bbox: Optional[BoxCoords] = None
#     column_index: int
#     row_index: int
#     colspan: int = 1
#     rowspan: int = 1
# ```
#
# ### Figure Structure
# Figures and images are represented as `MarkdownFigure` objects with rich metadata:
#
# ```python
# class MarkdownFigure:
#     id: int  # Reference ID (e.g., 0)
#     title: Optional[str] = None
#     caption: Optional[str] = None
#     content: Optional[str] = None  # Figure description
#     bbox: Optional[BoxCoords] = None
#
#     # Methods
#     def render(self) -> str  # HTML figure rendering
# ```

# %% [markdown]
# ## Example Files
#
# The following example files are used throughout this cookbook:
#
# 1. **Presentation Deck** ([`fine-tuning-deck.pdf`](https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.markdown/fine-tuning-deck.pdf))
#    - Multi-page presentation with mixed content
#    - Contains text, tables, charts, and diagrams
#    - Ideal for testing multi-page processing
#
# 2. **Single Table Document** ([`earnings_single_table.pdf`](https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.markdown/earnings_single_table.pdf))
#    - Financial table with structured data
#    - Perfect for testing table extraction
#
# 3. **Hardware Specification Sheet** ([`AD74413R.pdf`](https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.markdown/AD74413R.pdf))
#    - Technical document with specifications
#    - Contains structured data and technical details
#
# 4. **Business Report** ([`bcgxaltagamma-true-luxury-global-consumer-insight-2021.pdf`](https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.markdown/bcgxaltagamma-true-luxury-global-consumer-insight-2021.pdf))
#    - Comprehensive report with mixed content
#    - Contains text, tables, and visualizations

# %% [markdown]
# ### Environment Setup
#
# To get started, install the VLM Run Python SDK and sign-up for an API key on the [VLM Run App](https://app.vlm.run).
# - Store the VLM Run API key under the `VLMRUN_API_KEY` environment variable.

# %% [markdown]
# ## Prerequisites
#
# * Python 3.9+
# * VLM Run API key (get one at [app.vlm.run](https://app.vlm.run))

# %% [markdown]
# ## Setup
#
# First, let's install the required packages:

# %%
! pip install vlmrun --upgrade --quiet
! pip install vlmrun-hub --upgrade --quiet

# %%
import os
import getpass

VLMRUN_BASE_URL = os.getenv("VLMRUN_BASE_URL", "https://api.vlm.run/v1")
VLMRUN_API_KEY = os.getenv("VLMRUN_API_KEY", None)
if VLMRUN_API_KEY is None:
    VLMRUN_API_KEY = getpass.getpass()
# Out:
#  ········

# %% [markdown]
# Let's initialize the VLM Run Client

# %%
from vlmrun.client import VLMRun

client = VLMRun(base_url=VLMRUN_BASE_URL, api_key=VLMRUN_API_KEY)

# %% [markdown]
# Let's start with a simple example - processing a presentation deck and viewing its contents:

# %%
from IPython.display import display, HTML
import requests
import base64

# Example presentation deck
PRESENTATION_URL = "https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.markdown/fine-tuning-deck.pdf"

# First, let's display the PDF to see what we're working with
def display_pdf(url: str, width: int = 800, height: int = 600):
    """Display a PDF from a URL in a notebook."""
    response = requests.get(url)
    pdf_data = base64.b64encode(response.content).decode('utf-8')
    pdf_html = f"""
    <div style="margin: 20px 0;">
        <iframe
            src="data:application/pdf;base64,{pdf_data}"
            width="{width}"
            height="{height}"
            style="border: 1px solid #ddd; border-radius: 4px;"
        ></iframe>
    </div>
    """
    display(HTML(pdf_html))

# Display the PDF
display_pdf(PRESENTATION_URL)
# Out:
#     <div style="margin: 20px 0;">
#         <iframe
#             src="data:application/pdf;base64,..."
#             width="800"
#             height="600"
#             style="border: 1px solid #ddd; border-radius: 4px;"
#         ></iframe>
#     </div>

# %%
# Now, let's process the document
prediction = client.document.generate(
    domain="document.markdown",
    url=PRESENTATION_URL,
    batch=True
)

# Wait for completion
prediction = client.predictions.wait(prediction.id)

if prediction.status == "completed":
    result = prediction.response
    print(f"Successfully processed document with {len(result.pages)} pages")
else:
    print(f"Processing failed: {prediction.status}")
# Out:
# Successfully processed document with 7 pages

# %% [markdown]
# ## Understanding the Response
#
# The application returns a structured response that contains the document's content in a markdown format. Let's examine what we got:

# %%
# Access the MarkdownDocument response
document = prediction.response

# Process each page
for i, page in enumerate(document.pages):
    print(f"\nPage {i+1}:")
    print("=" * 80)
    
    # Display rendered content  
    print("\nContent:")
    print(page.markdown_content)
    
    # Show what we found on this page
    stats = {
        "Tables": len(page.tables) if page.tables else 0,
        "Figures": len(page.figures) if page.figures else 0
    }
    print("\nPage Statistics:")
    for stat, value in stats.items():
        print(f"- {stat}: {value}")
# Out:
# Page 1:
# ================================================================================
#
# Content:
# <Figure id="fg-0"/>
#
# OpenAI logo
#
# # Fine-tuning
# Technique
#
# ---
#
# February 2024
#
# Page Statistics:
# - Tables: 0
# - Figures: 2
#
# Page 2:
# ================================================================================
#
# Content:
# # Overview
#
# Fine-tuning involves adjusting the parameters of pre-trained models on a specific dataset or task. This process enhances the model's ability to generate more accurate and relevant responses for the given context by adapting it to the nuances and specific requirements of the task at hand.
#
# ## Example use cases
#
# - Generate output in a consistent format
# - Process input by following specific instructions
#
# ## What we'll cover
#
# - When to fine-tune
# - Preparing the dataset
# - Best practices
# - Hyperparameters
# - Fine-tuning advances
# - Resources
#
# 3
#
# Page Statistics:
# - Tables: 0
# - Figures: 0
#
# Page 3:
# ================================================================================
#
# Content:
# # What is Fine-tuning
#
# <Figure id="fg-0"/>
#
# Diagram illustrating the fine-tuning process: A Public Model and Training data are inputs to Training, which results in a Fine-tuned model.
#
# Fine-tuning a model consists of training the model to follow a set of given input/output examples.
#
# This will teach the model to behave in a certain way when confronted with a similar input in the future.
#
# > We recommend using 50-100 examples even if the minimum is 10.
#
# 4
#
# Page Statistics:
# - Tables: 0
# - Figures: 1
#
# Page 4:
# ================================================================================
#
# Content:
# # When to fine-tune
#
# <Figure id="fg-0"/>
#
# Section header indicating beneficial scenarios for fine-tuning, accompanied by a green checkmark graphic.
# **Good for** ✅
#
# *   Following a given format or tone for the output
# *   Processing the input following specific, complex instructions
# *   Improving latency
# *   Reducing token usage
#
# <Figure id="fg-1"/>
#
# Section header indicating scenarios where fine-tuning is not recommended, accompanied by a red cross graphic.
# **Not good for** ❌
#
# *   Teaching the model new knowledge
#     → Use RAG or custom models instead
# *   Performing well at multiple, unrelated tasks
#     → Do prompt-engineering or create multiple FT models instead
# *   Include up-to-date content in responses
#     → Use RAG instead
#
# <!-- PageNumber="5" -->
#
#
# Page Statistics:
# - Tables: 0
# - Figures: 2
#
# Page 5:
# ================================================================================
#
# Content:
# # Preparing the dataset
#
# ## Example format
#
# {
# "messages": [
# {
# "role": "system",
# "content": "Marv is a factual chatbot
# that is also sarcastic."
# },
# {
# "role": "user",
# "content": "What's the capital of
# France?"
# },
# {
# "role": "assistant",
# "content": "Paris, as if everyone
# doesn't know that already."
# }
#
# ]
#
# }.jsonl
#
# - Take the set of instructions and prompts that you
# found worked best for the model prior to fine-tuning.
# Include them in every training example
#
# - If you would like to shorten the instructions or
# prompts, it may take more training examples to arrive
# at good results
#
# We recommend using 50-100 examples
# even if the minimum is 10.
#
# OpenA16
#
# Page Statistics:
# - Tables: 0
# - Figures: 0
#
# Page 6:
# ================================================================================
#
# Content:
# # Best practices
#
# ## Curate examples carefully
#
# Datasets can be difficult to build, start
# small and invest intentionally.
# Optimize for fewer high-quality
# training examples.
#
# *   Consider "prompt baking", or using a basic
#     prompt to generate your initial examples
# *   If your conversations are multi-turn, ensure
#     your examples are representative
# *   Collect examples to target issues detected
#     in evaluation
# *   Consider the balance & diversity of data
# *   Make sure your examples contain all the
#     information needed in the response
#
# ## Iterate on hyperparameters
#
# Start with the defaults and adjust
# based on performance.
#
# *   If the model does not appear to converge,
#     increase the learning rate multiplier
# *   If the model does not follow the training
#     data as much as expected increase the
#     number of epochs
# *   If the model becomes less diverse than
#     expected decrease the # of epochs by 1-2
#
# ## Automate your feedback pipeline
#
# Introduce automated evaluations to
# highlight potential problem cases to
# clean up and use as training data.
#
# Consider the G-Eval approach of
# using GPT-4 to perform automated
# testing using a scorecard.
#
# <Figure id="fg-0"/>
#
#
#
# ## Establish a baseline
#
# Often users start with a
# zero-shot or few-shot prompt to
# build a baseline evaluation
# before graduating to fine-tuning.
#
# ## Optimize for latency and
# token efficiency
#
# When using GPT-4, once you
# have a baseline evaluation and
# training examples consider
# fine-tuning 3.5 to get similar
# performance for less cost and
# latency.
#
# Experiment with reducing or
# removing system instructions
# with subsequent fine-tuned
# model versions.
#
# Page Statistics:
# - Tables: 0
# - Figures: 1
#
# Page 7:
# ================================================================================
#
# Content:
# # Hyperparameters
#
# ## Epochs
#
# Refers to 1 full cycle through the training dataset
#
# default: auto (standard is 4)
#
# If you have hundreds of thousands of examples, we would recommend experimenting with two epochs (or one) to avoid overfitting.
#
# ## Batch size
#
# Number of training examples used to train a single forward & backward pass
#
# default: ~0.2% x N* (max 256)
#
# *N = number of training examples
#
# In general, we've found that larger batch sizes tend to work better for larger datasets
#
# ## Learning rate multiplier
#
# Scaling factor for the original learning rate
#
# default: 0.05, 0.1 or 0.2*
#
# *depends on final batch size
#
# We recommend experimenting with values between 0.02-0.2. We've found that larger learning rates often perform better with larger batch sizes.
#
# 8
#
# Page Statistics:
# - Tables: 0
# - Figures: 0

# %% [markdown]
# ## Working with Tables
#
# The application excels at extracting tables from documents. Let's look at a document that contains a table:

# %%
TABLE_URL = "https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.markdown/earnings_single_table.pdf"

# Display the PDF
display_pdf(TABLE_URL)
# Out:
#     <div style="margin: 20px 0;">
#         <iframe
#             src="data:application/pdf;base64,..."
#             width="800"
#             height="600"
#             style="border: 1px solid #ddd; border-radius: 4px;"
#         ></iframe>
#     </div>

# %%
prediction = client.document.generate(
    domain="document.markdown",
    url=TABLE_URL,
    batch=True
)

# Wait for completion
prediction = client.predictions.wait(prediction.id)

if prediction.status == "completed":
    document = prediction.response
    
    # Process each page
    for page in document.pages:
        if page.tables:
            for i, table in enumerate(page.tables):
                print(f"\nTable {i+1}:")
                print("=" * 80)
                
                # Display table metadata
                if table.metadata.title:
                    print(f"Title: {table.metadata.title}")
                if table.metadata.caption:
                    print(f"Caption: {table.metadata.caption}")
                
                # Display table headers  
                if table.headers:
                    print("\nHeaders:")
                    for header in table.headers:
                        print(f"- {header.name} ({header.dtype})")
                
                # Convert to DataFrame for easy viewing
                if hasattr(table, 'to_dataframe'):
                    df = table.to_dataframe()
                    print("\nTable Data:")
                    print(df)
                
                # Or access raw data
                print("\nRaw Data:")
                for row in table.data:
                    print(row)
# Out:
# Table 1:
# ================================================================================
#
# Headers:
# - Year (int)
# - Partially Funded (currency)
# - Wholly Unfunded (currency)
# - Total (currency)
#
# Table Data:
#   year_0 partially_funded_1 wholly_unfunded_2    total_3
# 0   2023             $ 12.6               $ —     $ 12.6
# 1   2022          $ (145.0)               $ —  $ (145.0)
#
# Raw Data:
# {'year_0': '2023', 'partially_funded_1': '$ 12.6', 'wholly_unfunded_2': '$ —', 'total_3': '$ 12.6'}
# {'year_0': '2022', 'partially_funded_1': '$ (145.0)', 'wholly_unfunded_2': '$ —', 'total_3': '$ (145.0)'}
#
# Table 2:
# ================================================================================
#
# Headers:
# - Assumption (str)
# - Partially Funded (percentage)
# - Wholly Unfunded (percentage)
# - Total (percentage)
#
# Table Data:
#                                         assumption_0 partially_funded_1  \
# 0                  December 31, 2023 > Discount rate              4.15%
# 1  December 31, 2023 > Expected rate of compensat...              1.67%
# 2                  December 31, 2022 > Discount rate              4.45%
# 3  December 31, 2022 > Expected rate of compensat...              1.71%
#
#   wholly_unfunded_2 total_3
# 0             4.62%   4.35%
# 1             2.63%   2.37%
# 2             4.35%   4.41%
# 3             2.57%   2.35%
#
# Raw Data:
# {'assumption_0': 'December 31, 2023 > Discount rate', 'partially_funded_1': '4.15%', 'wholly_unfunded_2': '4.62%', 'total_3': '4.35%'}
# {'assumption_0': 'December 31, 2023 > Expected rate of compensation increase', 'partially_funded_1': '1.67%', 'wholly_unfunded_2': '2.63%', 'total_3': '2.37%'}
# {'assumption_0': 'December 31, 2022 > Discount rate', 'partially_funded_1': '4.45%', 'wholly_unfunded_2': '4.35%', 'total_3': '4.41%'}
# {'assumption_0': 'December 31, 2022 > Expected rate of compensation increase', 'partially_funded_1': '1.71%', 'wholly_unfunded_2': '2.57%', 'total_3': '2.35%'}
#
# Table 3:
# ================================================================================
#
# Headers:
# - Assumption (str)
# - Partially Funded (percentage)
# - Wholly Unfunded (percentage)
# - Total (percentage)
#
# Table Data:
#                                         assumption_0 partially_funded_1  \
# 0                  December 31, 2023 > Discount rate              4.45%
# 1  December 31, 2023 > Expected rate of compensat...              1.71%
# 2                  December 31, 2022 > Discount rate              1.84%
# 3  December 31, 2022 > Expected rate of compensat...              1.48%
#
#   wholly_unfunded_2 total_3
# 0             4.34%   4.40%
# 1             2.56%   2.35%
# 2             1.54%   1.73%
# 3             2.05%   1.92%
#
# Raw Data:
# {'assumption_0': 'December 31, 2023 > Discount rate', 'partially_funded_1': '4.45%', 'wholly_unfunded_2': '4.34%', 'total_3': '4.40%'}
# {'assumption_0': 'December 31, 2023 > Expected rate of compensation increase', 'partially_funded_1': '1.71%', 'wholly_unfunded_2': '2.56%', 'total_3': '2.35%'}
# {'assumption_0': 'December 31, 2022 > Discount rate', 'partially_funded_1': '1.84%', 'wholly_unfunded_2': '1.54%', 'total_3': '1.73%'}
# {'assumption_0': 'December 31, 2022 > Expected rate of compensation increase', 'partially_funded_1': '1.48%', 'wholly_unfunded_2': '2.05%', 'total_3': '1.92%'}
#
# Table 4:
# ================================================================================
#
# Headers:
# - Sensitivity Item (str)
# - Partially Funded (str)
# - Wholly Unfunded (str)
#
# Table Data:
#             sensitivity_item_0 partially_funded_1 wholly_unfunded_2
# 0  Discount rate (increase 1%)           $ (42.6)          $ (17.2)
# 1  Discount rate (decrease 1%)             $ 46.3            $ 18.5
# 2          Longevity (+1 year)              $ 7.6             $ 7.3
# 3           Inflation (+0.25%)              $ 6.6               $ —
# 4           Inflation (-0.25%)            $ (6.1)               $ —
# 5         Salary (increase 1%)              $ 3.0             $ 2.8
# 6         Salary (decrease 1%)            $ (2.2)           $ (2.5)
# 7             Duration (years)                 15                10
#
# Raw Data:
# {'sensitivity_item_0': 'Discount rate (increase 1%)', 'partially_funded_1': '$ (42.6)', 'wholly_unfunded_2': '$ (17.2)'}
# {'sensitivity_item_0': 'Discount rate (decrease 1%)', 'partially_funded_1': '$ 46.3', 'wholly_unfunded_2': '$ 18.5'}
# {'sensitivity_item_0': 'Longevity (+1 year)', 'partially_funded_1': '$ 7.6', 'wholly_unfunded_2': '$ 7.3'}
# {'sensitivity_item_0': 'Inflation (+0.25%)', 'partially_funded_1': '$ 6.6', 'wholly_unfunded_2': '$ —'}
# {'sensitivity_item_0': 'Inflation (-0.25%)', 'partially_funded_1': '$ (6.1)', 'wholly_unfunded_2': '$ —'}
# {'sensitivity_item_0': 'Salary (increase 1%)', 'partially_funded_1': '$ 3.0', 'wholly_unfunded_2': '$ 2.8'}
# {'sensitivity_item_0': 'Salary (decrease 1%)', 'partially_funded_1': '$ (2.2)', 'wholly_unfunded_2': '$ (2.5)'}
# {'sensitivity_item_0': 'Duration (years)', 'partially_funded_1': '15', 'wholly_unfunded_2': '10'}

# %% [markdown]
# ## Working with Figures
#
# The application can also extract and describe figures from documents. Let's look at a document with figures:

# %%
REPORT_URL = "https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.markdown/bcgxaltagamma-true-luxury-global-consumer-insight-2021.pdf"

prediction = client.document.generate(
    domain="document.markdown",
    url=REPORT_URL,
    batch=True
)

# Wait for completion
prediction = client.predictions.wait(prediction.id, 300)

if prediction.status == "completed":
    document = prediction.response
    
    # Process each page
    for page_num, page in enumerate(document.pages, 1):
        if page.figures:
            print(f"\nPage {page_num} Figures:")
            print("=" * 80)
            
            for i, figure in enumerate(page.figures):
                print(f"\nFigure {i+1}:")
                if figure.title:
                    print(f"Title: {figure.title}")
                if figure.caption:
                    print(f"Caption: {figure.caption}")
                print(f"Description: {figure.content}")
                
                # Use the render method if available
                if hasattr(figure, 'render'):
                    rendered = figure.render()
                    print(f"Rendered: {rendered}")
# Out:
# Page 1 Figures:
# ================================================================================
#
# Figure 1:
# Description: A woman's profile with eyes closed, illuminated by sunlight casting shadows.
# Rendered: <Figure id="fg-0"/>
#
# A woman's profile with eyes closed, illuminated by sunlight casting shadows.
#
# Page 2 Figures:
# ================================================================================
#
# Figure 1:
# Description: A black and white image of a person standing on a road looking towards the horizon with a green glow behind them.
# Rendered: <Figure id="fg-0"/>
#
# A black and white image of a person standing on a road looking towards the horizon with a green glow behind them.
#
# Figure 2:
# Description: The logos for BCG and ALTAGAMMA CREATIVITÀ E CULTURA ITALIANA.
# Rendered: <Figure id="fg-1"/>
#
# The logos for BCG and ALTAGAMMA CREATIVITÀ E CULTURA ITALIANA.
#
# Page 3 Figures:
# ================================================================================
#
# Figure 1:
# Description: ~19M number inside a circle graphic
# Rendered: <Figure id="fg-0"/>
#
# ~19M number inside a circle graphic
#
# Figure 2:
# Description: Image representing respondents (people)
# Rendered: <Figure id="fg-1"/>
#
# Image representing respondents (people)
#
# Figure 3:
# Description: Image representing average spend (shopping bags)
# Rendered: <Figure id="fg-2"/>
#
# Image representing average spend (shopping bags)
#
# Figure 4:
# Description: Image representing markets (flags of various countries)
# Rendered: <Figure id="fg-3"/>
#
# Image representing markets (flags of various countries)
#
# Figure 5:
# Description: BCG x ALTAGAMMA logo
# Rendered: <Figure id="fg-4"/>
#
# BCG x ALTAGAMMA logo
#
# Figure 6:
# Description: PHRONESISPARTNERS simplifygrowth logo
# Rendered: <Figure id="fg-5"/>
#
# PHRONESISPARTNERS simplifygrowth logo
#
# Page 4 Figures:
# ================================================================================
#
# Figure 1:
# Caption: Note: List of brands not exhaustive
# Description: A Venn diagram illustrating the collaboration between BCG partners and Altagamma partners for the "True-luxury Consumer Insight 2021". The left circle "BCG partners" includes: HIGHSNOBIETY, BERNSTEIN, Alibaba.com, Google, FASHION FOR D, Tencent, Sustainable Apparel Coalition. The right circle "Altagamma partners" includes: BELMOND, MONCLER, B&B ITALIA, Salvatore Ferragamo, LAMBORGHINI, KERING, FERRARI, OTB, BRUNELLO CUCINELLI, TOD'S, GUCCI, MaxMara, RENE CAOVILLA, BVLGARI, ORNELLAIA, DOLCE & GABBANA, TIFFANY & CO., ACQUA DI PARMA, Zegna, illy, YOOX NET-A-PORTER GROUP, VERSACE, FENDI ROMA, Loro Piana, TECHNOGYM, HERNO, Pomellato, BOTTEGA VENETA, VALENTINO, LUXOTTICA, PRADA, RINASCENTE. The overlapping area is labeled "True-luxury Consumer Insight 2021".
# Rendered: <Figure id="fg-0"/>
#
# A Venn diagram illustrating the collaboration between BCG partners and Altagamma partners for the "True-luxury Consumer Insight 2021". The left circle "BCG partners" includes: HIGHSNOBIETY, BERNSTEIN, Alibaba.com, Google, FASHION FOR D, Tencent, Sustainable Apparel Coalition. The right circle "Altagamma partners" includes: BELMOND, MONCLER, B&B ITALIA, Salvatore Ferragamo, LAMBORGHINI, KERING, FERRARI, OTB, BRUNELLO CUCINELLI, TOD'S, GUCCI, MaxMara, RENE CAOVILLA, BVLGARI, ORNELLAIA, DOLCE & GABBANA, TIFFANY & CO., ACQUA DI PARMA, Zegna, illy, YOOX NET-A-PORTER GROUP, VERSACE, FENDI ROMA, Loro Piana, TECHNOGYM, HERNO, Pomellato, BOTTEGA VENETA, VALENTINO, LUXOTTICA, PRADA, RINASCENTE. The overlapping area is labeled "True-luxury Consumer Insight 2021".
#
# Page 5 Figures:
# ================================================================================
#
# Figure 1:
# Description: Brad
# Baker
# Rendered: <Figure id="fg-0"/>
#
# Brad
# Baker
#
# Figure 2:
# Description: Christine
# Barton
# Rendered: <Figure id="fg-1"/>
#
# Christine
# Barton
#
# Figure 3:
# Description: Kunal
# Bhatia
# Rendered: <Figure id="fg-2"/>
#
# Kunal
# Bhatia
#
# Figure 4:
# Description: Joppe
# Bijlsma
# Rendered: <Figure id="fg-3"/>
#
# Joppe
# Bijlsma
#
# Figure 5:
# Description: Thierry
# Chassaing
# Rendered: <Figure id="fg-4"/>
#
# Thierry
# Chassaing
#
# Figure 6:
# Description: Abhishek
# Dalmia
# Rendered: <Figure id="fg-5"/>
#
# Abhishek
# Dalmia
#
# Figure 7:
# Description: Pierre
# Dupreelle
# Rendered: <Figure id="fg-6"/>
#
# Pierre
# Dupreelle
#
# Figure 8:
# Description: Andres
# Garro
# Rendered: <Figure id="fg-7"/>
#
# Andres
# Garro
#
# Figure 9:
# Description: Erin
# George
# Rendered: <Figure id="fg-8"/>
#
# Erin
# George
#
# Figure 10:
# Description: Nicholas
# Goad
# Rendered: <Figure id="fg-9"/>
#
# Nicholas
# Goad
#
# Figure 11:
# Description: Chris
# Goodchild
# Rendered: <Figure id="fg-10"/>
#
# Chris
# Goodchild
#
# Figure 12:
# Description: John
# Haugh
# Rendered: <Figure id="fg-11"/>
#
# John
# Haugh
#
# Figure 13:
# Description: Ganga
# Kannan
# Rendered: <Figure id="fg-12"/>
#
# Ganga
# Kannan
#
# Figure 14:
# Description: Bharat
# Khandelwal
# Rendered: <Figure id="fg-13"/>
#
# Bharat
# Khandelwal
#
# Figure 15:
# Description: Robbin
# Mitchell
# Rendered: <Figure id="fg-14"/>
#
# Robbin
# Mitchell
#
# Figure 16:
# Description: Steve
# Mitchelmore
# Rendered: <Figure id="fg-15"/>
#
# Steve
# Mitchelmore
#
# Figure 17:
# Description: Suchi
# Sastri
# Rendered: <Figure id="fg-16"/>
#
# Suchi
# Sastri
#
# Figure 18:
# Description: Jeffrey
# Shaddix
# Rendered: <Figure id="fg-17"/>
#
# Jeffrey
# Shaddix
#
# Figure 19:
# Description: Jeremy
# Sporn
# Rendered: <Figure id="fg-18"/>
#
# Jeremy
# Sporn
#
# Figure 20:
# Description: Drake
# Watten
# Rendered: <Figure id="fg-19"/>
#
# Drake
# Watten
#
# Figure 21:
# Description: Sarah
# Willersdorf
# Rendered: <Figure id="fg-20"/>
#
# Sarah
# Willersdorf
#
# Figure 22:
# Description: Tiffany
# Yeh
# Rendered: <Figure id="fg-21"/>
#
# Tiffany
# Yeh
#
# Figure 23:
# Description: Rene
# Abate
# Rendered: <Figure id="fg-22"/>
#
# Rene
# Abate
#
# Figure 24:
# Description: Filippo
# Bianchi
# Rendered: <Figure id="fg-23"/>
#
# Filippo
# Bianchi
#
# Figure 25:
# Description: Sebastian
# Boger
# Rendered: <Figure id="fg-24"/>
#
# Sebastian
# Boger
#
# Figure 26:
# Description: Irene
# Boni
# Rendered: <Figure id="fg-25"/>
#
# Irene
# Boni
#
# Figure 27:
# Description: Stephane
# Cairole
# Rendered: <Figure id="fg-26"/>
#
# Stephane
# Cairole
#
# Figure 28:
# Description: Guillaume
# Charlin
# Rendered: <Figure id="fg-27"/>
#
# Guillaume
# Charlin
#
# Figure 29:
# Description: Elisa
# Crotti
# Rendered: <Figure id="fg-28"/>
#
# Elisa
# Crotti
#
# Figure 30:
# Description: Olof
# Darpo
# Rendered: <Figure id="fg-29"/>
#
# Olof
# Darpo
#
# Figure 31:
# Description: Nicolas
# De Bellefonds
# Rendered: <Figure id="fg-30"/>
#
# Nicolas
# De Bellefonds
#
# Figure 32:
# Description: Jessica
# Distler
# Rendered: <Figure id="fg-31"/>
#
# Jessica
# Distler
#
# Figure 33:
# Description: Patrick
# Ducasse
# Rendered: <Figure id="fg-32"/>
#
# Patrick
# Ducasse
#
# Figure 34:
# Description: Volker
# Haemmerle
# Rendered: <Figure id="fg-33"/>
#
# Volker
# Haemmerle
#
# Figure 35:
# Description: Joël
# Hazan
# Rendered: <Figure id="fg-34"/>
#
# Joël
# Hazan
#
# Figure 36:
# Description: Dominic
# Klemmer
# Rendered: <Figure id="fg-35"/>
#
# Dominic
# Klemmer
#
# Figure 37:
# Description: Asli
# Kurbay
# Rendered: <Figure id="fg-36"/>
#
# Asli
# Kurbay
#
# Figure 38:
# Description: Francesco
# Leone
# Rendered: <Figure id="fg-37"/>
#
# Francesco
# Leone
#
# Figure 39:
# Description: Andreas
# Liedtke
# Rendered: <Figure id="fg-38"/>
#
# Andreas
# Liedtke
#
# Figure 40:
# Description: Andreas
# Malby
# Rendered: <Figure id="fg-39"/>
#
# Andreas
# Malby
#
# Figure 41:
# Description: Kirstin
# Mennella
# Rendered: <Figure id="fg-40"/>
#
# Kirstin
# Mennella
#
# Figure 42:
# Description: Pierre
# Mercier
# Rendered: <Figure id="fg-41"/>
#
# Pierre
# Mercier
#
# Figure 43:
# Description: Nicola
# Pianon
# Rendered: <Figure id="fg-42"/>
#
# Nicola
# Pianon
#
# Figure 44:
# Description: Stefan
# Rasch
# Rendered: <Figure id="fg-43"/>
#
# Stefan
# Rasch
#
# Figure 45:
# Description: Stefan
# Rohrhofer
# Rendered: <Figure id="fg-44"/>
#
# Stefan
# Rohrhofer
#
# Figure 46:
# Description: Dan
# Sack
# Rendered: <Figure id="fg-45"/>
#
# Dan
# Sack
#
# Figure 47:
# Description: Matthias
# Schuler
# Rendered: <Figure id="fg-46"/>
#
# Matthias
# Schuler
#
# Figure 48:
# Description: Javier
# Seara
# Rendered: <Figure id="fg-47"/>
#
# Javier
# Seara
#
# Figure 49:
# Description: Joan
# Sol
# Rendered: <Figure id="fg-48"/>
#
# Joan
# Sol
#
# Figure 50:
# Description: Luca
# Solca
# Rendered: <Figure id="fg-49"/>
#
# Luca
# Solca
#
# Figure 51:
# Description: Lars
# Sorensen
# Rendered: <Figure id="fg-50"/>
#
# Lars
# Sorensen
#
# Figure 52:
# Description: Emil
# Stamp
# Rendered: <Figure id="fg-51"/>
#
# Emil
# Stamp
#
# Figure 53:
# Description: Christina
# Synnergren
# Rendered: <Figure id="fg-52"/>
#
# Christina
# Synnergren
#
# Figure 54:
# Description: Stefano
# Todescan
# Rendered: <Figure id="fg-53"/>
#
# Stefano
# Todescan
#
# Figure 55:
# Description: Diederik
# Vismans
# Rendered: <Figure id="fg-54"/>
#
# Diederik
# Vismans
#
# Figure 56:
# Description: Parul
# Bajaj
# Rendered: <Figure id="fg-55"/>
#
# Parul
# Bajaj
#
# Figure 57:
# Description: Colin
# Currie
# Rendered: <Figure id="fg-56"/>
#
# Colin
# Currie
#
# Figure 58:
# Description: Crystal
# Hao
# Rendered: <Figure id="fg-57"/>
#
# Crystal
# Hao
#
# Figure 59:
# Description: Jinseok
# Jang
# Rendered: <Figure id="fg-58"/>
#
# Jinseok
# Jang
#
# Figure 60:
# Description: Yeonhee
# Kim
# Rendered: <Figure id="fg-59"/>
#
# Yeonhee
# Kim
#
# Figure 61:
# Description: Vincent
# Lui
# Rendered: <Figure id="fg-60"/>
#
# Vincent
# Lui
#
# Figure 62:
# Description: Rachit
# Mathur
# Rendered: <Figure id="fg-61"/>
#
# Rachit
# Mathur
#
# Figure 63:
# Description: Jun
# Naito
# Rendered: <Figure id="fg-62"/>
#
# Jun
# Naito
#
# Figure 64:
# Description: Rohit
# Ramesh
# Rendered: <Figure id="fg-63"/>
#
# Rohit
# Ramesh
#
# Figure 65:
# Description: Michael
# Schniering
# Rendered: <Figure id="fg-64"/>
#
# Michael
# Schniering
#
# Figure 66:
# Description: Mani
# Singhal
# Rendered: <Figure id="fg-65"/>
#
# Mani
# Singhal
#
# Figure 67:
# Description: Joseph
# Sun
# Rendered: <Figure id="fg-66"/>
#
# Joseph
# Sun
#
# Figure 68:
# Description: Miki
# Tsusaka
# Rendered: <Figure id="fg-67"/>
#
# Miki
# Tsusaka
#
# Figure 69:
# Description: Jeffrey
# Walters
# Rendered: <Figure id="fg-68"/>
#
# Jeffrey
# Walters
#
# Figure 70:
# Description: Angela
# Wang
# Rendered: <Figure id="fg-69"/>
#
# Angela
# Wang
#
# Figure 71:
# Description: Veronique
# Yang
# Rendered: <Figure id="fg-70"/>
#
# Veronique
# Yang
#
# Page 6 Figures:
# ================================================================================
#
# Figure 1:
# Description: Image of a person wearing sunglasses.
# Rendered: <Figure id="fg-0"/>
#
# Image of a person wearing sunglasses.
#
# Figure 2:
# Description: Image of clothes on hangers.
# Rendered: <Figure id="fg-1"/>
#
# Image of clothes on hangers.
#
# Figure 3:
# Description: Image of a person holding a phone.
# Rendered: <Figure id="fg-2"/>
#
# Image of a person holding a phone.
#
# Figure 4:
# Description: Logos for BCG and ALTAGAMMA CREATIVITÀ E CULTURA ITALIANA.
# Rendered: <Figure id="fg-3"/>
#
# Logos for BCG and ALTAGAMMA CREATIVITÀ E CULTURA ITALIANA.
#
# Page 7 Figures:
# ================================================================================
#
# Figure 1:
# Description: Image of a man standing on a beach near the water.
# Rendered: <Figure id="fg-0"/>
#
# Image of a man standing on a beach near the water.
#
# Figure 2:
# Description: Footer area with BCG logo, ALTAGAMMA logo and tagline, page number 6, and copyright notice.
# Rendered: <Figure id="fg-1"/>
#
# Footer area with BCG logo, ALTAGAMMA logo and tagline, page number 6, and copyright notice.
#
# Page 8 Figures:
# ================================================================================
#
# Figure 1:
# Title: Global Luxury Market (Personal & Experiential), €B
# Description: Bar chart showing the Global Luxury Market value from 2014 to 2020 (actual) and 2021 to 2025 (projected), broken down by Personal and Experiential segments (as percentages). Key market values in €B are shown for selected years: 755 (2014), 966 (2019), 581 (2020), [820-870] (2021), [960-1020] (2022), [1030-1080] (2023), [1080-1130] (2024), [1090-1220] (2025).  The chart also includes CAGR ('14-'19: +4% Overall, +6% Experiential) and YOY ('19-'20: -22% Overall, -50% Experiential) values.  Evolution vs 2019 is shown for Personal (-5% '19-'21, +5% '19-'22, +8% '19-'23) and Experiential (+0% '19-'21, +10% '19-'22, +12% '19-'23). CAGR '19-'25 is shown for Personal (+2%) and Experiential (+4%).
# Rendered: <Figure id="fg-0"/>
#
# Bar chart showing the Global Luxury Market value from 2014 to 2020 (actual) and 2021 to 2025 (projected), broken down by Personal and Experiential segments (as percentages). Key market values in €B are shown for selected years: 755 (2014), 966 (2019), 581 (2020), [820-870] (2021), [960-1020] (2022), [1030-1080] (2023), [1080-1130] (2024), [1090-1220] (2025).  The chart also includes CAGR ('14-'19: +4% Overall, +6% Experiential) and YOY ('19-'20: -22% Overall, -50% Experiential) values.  Evolution vs 2019 is shown for Personal (-5% '19-'21, +5% '19-'22, +8% '19-'23) and Experiential (+0% '19-'21, +10% '19-'22, +12% '19-'23). CAGR '19-'25 is shown for Personal (+2%) and Experiential (+4%).
#
# Figure 2:
# Description: Logos for BCG and ALTAGAMMA. Page number 7.
# Rendered: <Figure id="fg-1"/>
#
# Logos for BCG and ALTAGAMMA. Page number 7.
#
# Page 9 Figures:
# ================================================================================
#
# Figure 1:
# Description: Image of a person wearing a beanie and sunglasses.
# Rendered: <Figure id="fg-0"/>
#
# Image of a person wearing a beanie and sunglasses.
#
# Figure 2:
# Description: Callout text: 53% believe recovery will be fast, compared to ~20% for older generations
# Rendered: <Figure id="fg-1"/>
#
# Callout text: 53% believe recovery will be fast, compared to ~20% for older generations
#
# Figure 3:
# Title: Luxury personal goods market (€B)
# Description: Stacked bar chart showing luxury personal goods market size and share by generation for 2019 and 2025 projection.
#
# 2019 Total: 349 €B
# - Baby Boomers and Silvers: 23%
# - Gen. X: 38%
# - Millennials: 35%
# - Gen. Z: 4%
#
# 2025 Projection Total: 390-440 €B
# - Baby Boomers and Silvers: 5-10%
# - Gen. X: 30-35%
# - Millennials: 45-50%
# - Gen. Z: 10-15%
#
# Total market share for Millennials and Gen Z in 2025 projection is 60+ %.
# Rendered: <Figure id="fg-2"/>
#
# Stacked bar chart showing luxury personal goods market size and share by generation for 2019 and 2025 projection.
#
# 2019 Total: 349 €B
# - Baby Boomers and Silvers: 23%
# - Gen. X: 38%
# - Millennials: 35%
# - Gen. Z: 4%
#
# 2025 Projection Total: 390-440 €B
# - Baby Boomers and Silvers: 5-10%
# - Gen. X: 30-35%
# - Millennials: 45-50%
# - Gen. Z: 10-15%
#
# Total market share for Millennials and Gen Z in 2025 projection is 60+ %.
#
# Figure 4:
# Description: Text box:
# New Gen influential on overall market through trendsetting, digital engagement
# New Gen share of spend growth largely **driven by increased average spend per person**
# Rendered: <Figure id="fg-3"/>
#
# Text box:
# New Gen influential on overall market through trendsetting, digital engagement
# New Gen share of spend growth largely **driven by increased average spend per person**
#
# Page 10 Figures:
# ================================================================================
#
# Figure 1:
# Description: Visual representation of the luxury consumer pyramid, segmented by income levels (50 k€, 20 k€, 10 k€, 5 k€, 2 k€) and corresponding clusters (Beyond money, Top absolute, Absolute, Entry absolute, Total true-luxury, Top aspirational, Other aspirational), presented alongside a table containing detailed population and market size data for 2019, 2020, and 2025.
# Rendered: <Figure id="fg-0"/>
#
# Visual representation of the luxury consumer pyramid, segmented by income levels (50 k€, 20 k€, 10 k€, 5 k€, 2 k€) and corresponding clusters (Beyond money, Top absolute, Absolute, Entry absolute, Total true-luxury, Top aspirational, Other aspirational), presented alongside a table containing detailed population and market size data for 2019, 2020, and 2025.
#
# Figure 2:
# Description: Logos for BCG and Altagamma CREATIVITÀ E CULTURA ITALIANA, followed by copyright information 'Copyright © 2021 by Boston Consulting Group. All rights reserved.' and the page number '9'.
# Rendered: <Figure id="fg-1"/>
#
# Logos for BCG and Altagamma CREATIVITÀ E CULTURA ITALIANA, followed by copyright information 'Copyright © 2021 by Boston Consulting Group. All rights reserved.' and the page number '9'.
#
# Page 11 Figures:
# ================================================================================
#
# Figure 1:
# Title: Average delta spending
# Description: Bar chart showing expected luxury spending changes in the next 12 months compared to before COVID-19, broken down by luxury products vs. luxury experiences and country of residence vs. abroad. Shows percentage distribution for 'A lot more (+50% or more)', 'A bit more (+20%)', 'About the same', 'A bit less (-20%)', and 'A lot less (-50% or more)' for each group, along with the overall average delta percentage (+2.5% for products/residence, -4.7% for products/abroad, +2.4% for experiences/residence, +14.1% for experiences/abroad).
# Rendered: <Figure id="fg-0"/>
#
# Bar chart showing expected luxury spending changes in the next 12 months compared to before COVID-19, broken down by luxury products vs. luxury experiences and country of residence vs. abroad. Shows percentage distribution for 'A lot more (+50% or more)', 'A bit more (+20%)', 'About the same', 'A bit less (-20%)', and 'A lot less (-50% or more)' for each group, along with the overall average delta percentage (+2.5% for products/residence, -4.7% for products/abroad, +2.4% for experiences/residence, +14.1% for experiences/abroad).
#
# Figure 2:
# Description: Logo/icon related to 'REBOUND EFFECT'.
# Rendered: <Figure id="fg-1"/>
#
# Logo/icon related to 'REBOUND EFFECT'.
#
# Page 12 Figures:
# ================================================================================
#
# Figure 1:
# Description: Image of a woman posing in a street with a coat.
# Rendered: <Figure id="fg-0"/>
#
# Image of a woman posing in a street with a coat.
#
# Figure 2:
# Description: BCG and ALTAGAMMA logos side by side with the text "CREATIVITÀ E CULTURA ITALIANA" below ALTAGAMMA.
# Rendered: <Figure id="fg-1"/>
#
# BCG and ALTAGAMMA logos side by side with the text "CREATIVITÀ E CULTURA ITALIANA" below ALTAGAMMA.
#
# Page 13 Figures:
# ================================================================================
#
# Figure 1:
# Description: A person walking in front of a modern building, with the text 'U.S. & China growth engines' superimposed on a green block.
# Rendered: <Figure id="fg-0"/>
#
# A person walking in front of a modern building, with the text 'U.S. & China growth engines' superimposed on a green block.
#
# Page 14 Figures:
# ================================================================================
#
# Figure 1:
# Description: Image of a man wearing a beanie and sunglasses, looking towards the camera.
# Rendered: <Figure id="fg-0"/>
#
# Image of a man wearing a beanie and sunglasses, looking towards the camera.
#
# Figure 2:
# Title: Expected delta in luxury spending, average %
# Caption: Note: Europe includes Italy, France, Germany and UK.
# Source: BCG-Altagamma True-Luxury Global Consumer Insight Survey Mar/Apr 21 (12K respondents in 12 countries), Expert interviews, BCG estimates
# Description: Bar chart showing the expected delta in luxury spending over the next 12 months for US, China, and Europe, split by Country of Residence and Abroad.
#
# US: Country of Residence +7.7%, Abroad +1.4%
# China: Country of Residence +6.0%, Abroad -5.6%
# Europe: Country of Residence -0.3%, Abroad -7.1%
#
# Callout for US consumers: forecasted to resume growth at a higher pace vs. pre-pandemic estimates, resulting in increased share of +2-3pp vs pre-covid forecasts, landing at 19-21% in 2025.
#
# Callout for Chinese consumers: expected to accelerate with respect to pre-crisis estimates, with increase in share of +3-4pp vs pre-covid, limited by US consumers' rebound, landing at 43-45% in 2025.
#
# Legend: Green bar represents Country of Residence, Dark green bar represents Abroad.
# Rendered: <Figure id="fg-1"/>
#
# Bar chart showing the expected delta in luxury spending over the next 12 months for US, China, and Europe, split by Country of Residence and Abroad.
#
# US: Country of Residence +7.7%, Abroad +1.4%
# China: Country of Residence +6.0%, Abroad -5.6%
# Europe: Country of Residence -0.3%, Abroad -7.1%
#
# Callout for US consumers: forecasted to resume growth at a higher pace vs. pre-pandemic estimates, resulting in increased share of +2-3pp vs pre-covid forecasts, landing at 19-21% in 2025.
#
# Callout for Chinese consumers: expected to accelerate with respect to pre-crisis estimates, with increase in share of +3-4pp vs pre-covid, limited by US consumers' rebound, landing at 43-45% in 2025.
#
# Legend: Green bar represents Country of Residence, Dark green bar represents Abroad.
#
# Page 15 Figures:
# ================================================================================
#
# Figure 1:
# Caption: Bar chart showing the share of luxury purchase abroad versus in China for 2016, 2019, and 2020, indicating a shift towards domestic spending.
# Description: Stacked bar chart showing Share of purchase abroad and Share of purchase in China for three years:
# - 2016: Share abroad 57%, Share in China 43%
# - 2019: Share abroad 56%, Share in China 44%
# - 2020: Share abroad 14%, Share in China 86%
# An arrow points from the 2020 bar upwards labeled '← 100%'
# Rendered: <Figure id="fg-0"/>
#
# Stacked bar chart showing Share of purchase abroad and Share of purchase in China for three years:
# - 2016: Share abroad 57%, Share in China 43%
# - 2019: Share abroad 56%, Share in China 44%
# - 2020: Share abroad 14%, Share in China 86%
# An arrow points from the 2020 bar upwards labeled '← 100%'
#
# Figure 2:
# Title: From half to all of it
# 69%
# Caption: Distribution of respondents' expected conversion of yearly luxury spend done abroad to their country of residence after the crisis.
# Description: Circular chart segments representing:
# - All of it: 13%
# - More than half: 56%
# - Less than half: 21%
# - None: 10%
# Rendered: <Figure id="fg-1"/>
#
# Circular chart segments representing:
# - All of it: 13%
# - More than half: 56%
# - Less than half: 21%
# - None: 10%
#
# Figure 3:
# Description: BCG and ALTAGAMMA logos.
# Rendered: <Figure id="fg-2"/>
#
# BCG and ALTAGAMMA logos.
#
# Page 16 Figures:
# ================================================================================
#
# Figure 1:
# Description: Image with the text "Virtualization" in a light blue box on the left and a partial view of a person wearing large dark sunglasses and a leather jacket on the right.
# Rendered: <Figure id="fg-0"/>
#
# Image with the text "Virtualization" in a light blue box on the left and a partial view of a person wearing large dark sunglasses and a leather jacket on the right.
#
# Page 17 Figures:
# ================================================================================
#
# Figure 1:
# Description: Image of a woman wearing large futuristic glasses.
# Rendered: <Figure id="fg-0"/>
#
# Image of a woman wearing large futuristic glasses.
#
# Figure 2:
# Description: Gamepad icon.
# Rendered: <Figure id="fg-1"/>
#
# Gamepad icon.
#
# Figure 3:
# Description: Dollar bill icon.
# Rendered: <Figure id="fg-2"/>
#
# Dollar bill icon.
#
# Figure 4:
# Description: Diamond icon.
# Rendered: <Figure id="fg-3"/>
#
# Diamond icon.
#
# Figure 5:
# Description: Icon of a person with a hood and goggles.
# Rendered: <Figure id="fg-4"/>
#
# Icon of a person with a hood and goggles.
#
# Figure 6:
# Description: BCG and ALTAGAMMA logos.
# Rendered: <Figure id="fg-5"/>
#
# BCG and ALTAGAMMA logos.
#
# Page 18 Figures:
# ================================================================================
#
# Figure 1:
# Description: Diagram showing survey results related to luxury consumers buying in-game items and physical versions. It includes three text bubbles representing survey questions and corresponding data visualizations.
#
# Text bubble 1: "Are you aware of luxury brands that lately have been interacting with their customers using virtual online games?"
# Data visualization 1: Bar chart showing Yes/No responses by region:
# - US: Yes 53%, No 47%
# - China: Yes 51%, No 49%
# - RoW: Yes 31%, No 69%
# - Europe: Yes 28%, No 72%
# Annotation: "Relevant for Chinese and US consumers"
#
# Overall Average Awareness: 39% (Yes) vs 61% (No)
#
# Text bubble 2 (Of those aware): "Have you ever been part of a virtual online game that involved a luxury brand and/or bought in-game items?"
# Data visualization 2 (Breakdown of 39% average): Flow/funnel showing:
# - Yes, and I bought in-game items: 55%
# - Yes, but I didn't buy in-game items: 33%
# - No, but I would consider playing: 9%
# - No, and I would not be interested: 2%
#
# Text bubble 3 (Of those who bought in-game items - the 55% group): "Afterwards, did you also buy the corresponding physical version of the item?"
# Data visualization 3 (Breakdown of the 55% group): Bar chart showing:
# - Yes, then bought corresponding physical version: 86%
# - No, but I would be interested: 13%
# - No, and I would not be interested: 1%
# Rendered: <Figure id="fg-0"/>
#
# Diagram showing survey results related to luxury consumers buying in-game items and physical versions. It includes three text bubbles representing survey questions and corresponding data visualizations.
#
# Text bubble 1: "Are you aware of luxury brands that lately have been interacting with their customers using virtual online games?"
# Data visualization 1: Bar chart showing Yes/No responses by region:
# - US: Yes 53%, No 47%
# - China: Yes 51%, No 49%
# - RoW: Yes 31%, No 69%
# - Europe: Yes 28%, No 72%
# Annotation: "Relevant for Chinese and US consumers"
#
# Overall Average Awareness: 39% (Yes) vs 61% (No)
#
# Text bubble 2 (Of those aware): "Have you ever been part of a virtual online game that involved a luxury brand and/or bought in-game items?"
# Data visualization 2 (Breakdown of 39% average): Flow/funnel showing:
# - Yes, and I bought in-game items: 55%
# - Yes, but I didn't buy in-game items: 33%
# - No, but I would consider playing: 9%
# - No, and I would not be interested: 2%
#
# Text bubble 3 (Of those who bought in-game items - the 55% group): "Afterwards, did you also buy the corresponding physical version of the item?"
# Data visualization 3 (Breakdown of the 55% group): Bar chart showing:
# - Yes, then bought corresponding physical version: 86%
# - No, but I would be interested: 13%
# - No, and I would not be interested: 1%
#
# Figure 2:
# Description: BCG and ALTAGAMMA CREATIVITÀ E CULTURA ITALIANA logos.
# Rendered: <Figure id="fg-1"/>
#
# BCG and ALTAGAMMA CREATIVITÀ E CULTURA ITALIANA logos.
#
# Page 19 Figures:
# ================================================================================
#
# Figure 1:
# Description: Background image of a person looking at clothes.
# Rendered: <Figure id="fg-0"/>
#
# Background image of a person looking at clothes.
#
# Page 20 Figures:
# ================================================================================
#
# Figure 1:
# Title: Luxury market¹ Channel mix (%) and Luxury market¹ growth by channel, 2019-2023e (B€)
# Caption: Channel mix and contribution to market growth (%, B€)
# Description: A combined chart showing the channel mix of the luxury market in % for 2019, 2023e Pre-COVID, and 2023e Post-COVID, alongside a waterfall chart showing the growth of the luxury market by channel in B€ from 2019 to 2023e. Channels include Brand.com, Multi-brand platforms, Omni-channel incl. ROPO², and Offline.
# Rendered: <Figure id="fg-0"/>
#
# A combined chart showing the channel mix of the luxury market in % for 2019, 2023e Pre-COVID, and 2023e Post-COVID, alongside a waterfall chart showing the growth of the luxury market by channel in B€ from 2019 to 2023e. Channels include Brand.com, Multi-brand platforms, Omni-channel incl. ROPO², and Offline.
#
# Figure 2:
# Description: Logos for BCG and Altagamma, along with the page number.
# Rendered: <Figure id="fg-1"/>
#
# Logos for BCG and Altagamma, along with the page number.
#
# Page 21 Figures:
# ================================================================================
#
# Figure 1:
# Description: Stacked bar chart showing the perceived importance of a brand being multi-channel across different regions (Europe, US, China, RoW) and the average. The stacks represent importance levels: Not negotiable (Europe 9%, US 5%, China 13%, RoW 11%, Average 10%, total ~90% important/not negotiable), Important (Europe 38%, US 48%, China 42%, RoW 34%, Average 39%), Somewhat important (Europe 37%, US 34%, China 40%, RoW 39%, Average ~50% somewhat/not important), and Not important (Europe 16%, US 13%, China 4%, RoW 16%, Average 13%).
# Rendered: <Figure id="fg-0"/>
#
# Stacked bar chart showing the perceived importance of a brand being multi-channel across different regions (Europe, US, China, RoW) and the average. The stacks represent importance levels: Not negotiable (Europe 9%, US 5%, China 13%, RoW 11%, Average 10%, total ~90% important/not negotiable), Important (Europe 38%, US 48%, China 42%, RoW 34%, Average 39%), Somewhat important (Europe 37%, US 34%, China 40%, RoW 39%, Average ~50% somewhat/not important), and Not important (Europe 16%, US 13%, China 4%, RoW 16%, Average 13%).
#
# Figure 2:
# Description: Horizontal bar chart showing the percentage of respondents mentioning specific features they expect when interacting with their preferred luxury brand through multiple channels (only respondents selecting "Important" or "Not negotiable"). Features and percentages are: Consistent brand image (44%), Int. delivery services anywhere (42%), Same promotions on all channels (37%), Fast delivery services (36%), Exchange anywhere (36%), All channels recognizability (35%), Same assortment in all channels (35%), Reward across all channels (35%).
# Rendered: <Figure id="fg-1"/>
#
# Horizontal bar chart showing the percentage of respondents mentioning specific features they expect when interacting with their preferred luxury brand through multiple channels (only respondents selecting "Important" or "Not negotiable"). Features and percentages are: Consistent brand image (44%), Int. delivery services anywhere (42%), Same promotions on all channels (37%), Fast delivery services (36%), Exchange anywhere (36%), All channels recognizability (35%), Same assortment in all channels (35%), Reward across all channels (35%).
#
# Figure 3:
# Description: Logos for BCG and ALTAGAMMA, along with the copyright notice "Copyright © 2021 by Boston Consulting Group. All rights reserved." and page number 20.
# Rendered: <Figure id="fg-2"/>
#
# Logos for BCG and ALTAGAMMA, along with the copyright notice "Copyright © 2021 by Boston Consulting Group. All rights reserved." and page number 20.
#
# Page 22 Figures:
# ================================================================================
#
# Figure 1:
# Title: Greatest demand exists for personalization services ... Responses (%)
# Description: Bar chart showing customer responses (%) for different types of interactions or care from brands:
# - Personalization: ~72% (Increased vs last year)
# - Exclusive access to events and contents¹: ~58% (Increased vs last year)
# - Exclusive access to store / products and promos²: ~56% (Increased vs last year)
# - Engagement on news, novelties and products manufacturing (n.a.⁴): ~43%
# - Special product services³: ~16% (Decreased vs last year)
# - Delivery services anywhere (n.a.⁴): ~12%
# Rendered: <Figure id="fg-0"/>
#
# Bar chart showing customer responses (%) for different types of interactions or care from brands:
# - Personalization: ~72% (Increased vs last year)
# - Exclusive access to events and contents¹: ~58% (Increased vs last year)
# - Exclusive access to store / products and promos²: ~56% (Increased vs last year)
# - Engagement on news, novelties and products manufacturing (n.a.⁴): ~43%
# - Special product services³: ~16% (Decreased vs last year)
# - Delivery services anywhere (n.a.⁴): ~12%
#
# Figure 2:
# Title: ... through both digital and physical avenues Responses within personalization (%)
# Description: Bar chart showing customer responses within personalization (%):
# - Personalised Treatment In-store: ~39% (Physical and in-person)
# - Targeted recommendations: ~26% (Digital and omnichannel)
# - Recognised as same customer across channels: ~23% (Digital and omnichannel)
# - Personal shopper: ~12% (Physical and in-person)
# Rendered: <Figure id="fg-1"/>
#
# Bar chart showing customer responses within personalization (%):
# - Personalised Treatment In-store: ~39% (Physical and in-person)
# - Targeted recommendations: ~26% (Digital and omnichannel)
# - Recognised as same customer across channels: ~23% (Digital and omnichannel)
# - Personal shopper: ~12% (Physical and in-person)
#
# Figure 3:
# Description: BCG and Altagamma logos.
# Rendered: <Figure id="fg-2"/>
#
# BCG and Altagamma logos.
#
# Page 23 Figures:
# ================================================================================
#
# Figure 1:
# Description: A woman with sunglasses and shopping bags.
# Rendered: <Figure id="fg-0"/>
#
# A woman with sunglasses and shopping bags.
#
# Page 24 Figures:
# ================================================================================
#
# Figure 1:
# Title: Awareness of Livestream Shopping
# Description: Bar chart showing the percentage of respondents aware of livestream shopping platforms or physical stores offering sessions, split by region (China, US, RoW, Europe) and overall average, showing 'Yes' and 'No' percentages. China: Yes 73%, No 27%. US: Yes 55%, No 45%. RoW: Yes 37%, No 63%. Europe: Yes 30%, No 70%. Average: Yes 46%, No 54%.
# Rendered: <Figure id="fg-0"/>
#
# Bar chart showing the percentage of respondents aware of livestream shopping platforms or physical stores offering sessions, split by region (China, US, RoW, Europe) and overall average, showing 'Yes' and 'No' percentages. China: Yes 73%, No 27%. US: Yes 55%, No 45%. RoW: Yes 37%, No 63%. Europe: Yes 30%, No 70%. Average: Yes 46%, No 54%.
#
# Figure 2:
# Title: Purchase Behavior After Livestream Session
# Description: Stacked bar chart showing the percentage of respondents who bought luxury goods during or immediately after a livestream session, split by region (Europe, US, China, RoW) and overall average. Categories include 'Yes, during', 'Yes, immediately after', 'No, would consider', and 'No, would not consider'. Europe: Yes, during 36%, Yes, immediately after 34%, No, would consider 22%, No, would not consider 8%. US: Yes, during 53%, Yes, immediately after 27%, No, would consider 14%, No, would not consider 5%. China: Yes, during 43%, Yes, immediately after 20%, No, would consider 30%, No, would not consider 7%. RoW: Yes, during 40%, Yes, immediately after 30%, No, would consider 26%, No, would not consider 5%. Average: Yes, during 43%, Yes, immediately after 27%, No, would consider 24%, No, would not consider 6%.
# Rendered: <Figure id="fg-1"/>
#
# Stacked bar chart showing the percentage of respondents who bought luxury goods during or immediately after a livestream session, split by region (Europe, US, China, RoW) and overall average. Categories include 'Yes, during', 'Yes, immediately after', 'No, would consider', and 'No, would not consider'. Europe: Yes, during 36%, Yes, immediately after 34%, No, would consider 22%, No, would not consider 8%. US: Yes, during 53%, Yes, immediately after 27%, No, would consider 14%, No, would not consider 5%. China: Yes, during 43%, Yes, immediately after 20%, No, would consider 30%, No, would not consider 7%. RoW: Yes, during 40%, Yes, immediately after 30%, No, would consider 26%, No, would not consider 5%. Average: Yes, during 43%, Yes, immediately after 27%, No, would consider 24%, No, would not consider 6%.
#
# Figure 3:
# Description: BCG and Altagamma Logos
# Rendered: <Figure id="fg-2"/>
#
# BCG and Altagamma Logos
#
# Page 25 Figures:
# ================================================================================
#
# Figure 1:
# Description: Portrait of Stefania Lazzaroni
# Rendered: <Figure id="fg-0"/>
#
# Portrait of Stefania Lazzaroni
#
# Figure 2:
# Description: Portrait of Nicola Pianon
# Rendered: <Figure id="fg-1"/>
#
# Portrait of Nicola Pianon
#
# Figure 3:
# Description: Portrait of Javier Seara
# Rendered: <Figure id="fg-2"/>
#
# Portrait of Javier Seara
#
# Figure 4:
# Description: Portrait of Filippo Bianchi
# Rendered: <Figure id="fg-3"/>
#
# Portrait of Filippo Bianchi
#
# Figure 5:
# Description: Portrait of Sarah Willersdorf
# Rendered: <Figure id="fg-4"/>
#
# Portrait of Sarah Willersdorf
#
# Figure 6:
# Description: Portrait of Guia Ricci
# Rendered: <Figure id="fg-5"/>
#
# Portrait of Guia Ricci
#
# Figure 7:
# Description: Portrait of Filippo Prini
# Rendered: <Figure id="fg-6"/>
#
# Portrait of Filippo Prini
#
# Figure 8:
# Description: BCG and ALTAGAMMA logo
# Rendered: <Figure id="fg-7"/>
#
# BCG and ALTAGAMMA logo
#
# Page 26 Figures:
# ================================================================================
#
# Figure 1:
# Description: BCG logo crossed with ALTAGAMMA logo with text 'CREATIVITÀ E CULTURA ITALIANA'
# Rendered: <Figure id="fg-0"/>
#
# BCG logo crossed with ALTAGAMMA logo with text 'CREATIVITÀ E CULTURA ITALIANA'
#
# Figure 2:
# Description: PHRONESISPARTNERS logo with text 'simplifygrowth' below it
# Rendered: <Figure id="fg-1"/>
#
# PHRONESISPARTNERS logo with text 'simplifygrowth' below it

# %% [markdown]
# ## Rendering Markdown Content
#
# The client provides both raw and rendered markdown content. Here's how to preview the rendered markdown:

# %%
from IPython.display import Markdown

def render_markdown(markdown_content: str) -> None:
    """Render markdown content."""
    display(Markdown(markdown_content))

# Process a document
prediction = client.document.generate(
    domain="document.markdown",
    url=PRESENTATION_URL
)

# Wait for completion
prediction = client.predictions.wait(prediction.id)

# %%
if prediction.status == "completed":
    document = prediction.response
    
    # Render each page using the document object
    for page_num, page in enumerate(document.pages, 1):
        print(f"\nPage {page_num}:")
        print("=" * 80)
        render_markdown(page.markdown_content)
        
    # Alternative: Use document-level rendering if available
    if hasattr(document, 'render'):
        print("\nFull Document:")
        print("=" * 80)
        render_markdown(document.render())
# Out:
# Page 1:
# ================================================================================
# <Figure id="fg-0"/>
#
# OpenAI logo
#
# # Fine-tuning
# Technique
#
# ---
#
# February 2024
# Page 2:
# ================================================================================
# # Overview
#
# Fine-tuning involves adjusting the parameters of pre-trained models on a specific dataset or task. This process enhances the model's ability to generate more accurate and relevant responses for the given context by adapting it to the nuances and specific requirements of the task at hand.
#
# ## Example use cases
#
# - Generate output in a consistent format
# - Process input by following specific instructions
#
# ## What we'll cover
#
# - When to fine-tune
# - Preparing the dataset
# - Best practices
# - Hyperparameters
# - Fine-tuning advances
# - Resources
#
# <Figure id="fg-0"/>
#
#
#
# 3
# Page 3:
# ================================================================================
# # What is Fine-tuning
#
# <Figure id="fg-0"/>
#
# Diagram illustrating the fine-tuning process. It shows a Public Model and Training data as inputs to a Training step, which outputs a Fine-tuned model.
#
# Fine-tuning a model consists of training the
# model to follow a set of given input/output
# examples.
#
# This will teach the model to behave in a
# certain way when confronted with a similar
# input in the future.
#
# We recommend using 50-100 examples
# even if the minimum is 10.
# Page 4:
# ================================================================================
# # When to fine-tune
#
# ## Good for <Figure id="fg-0"/>
#
# Green checkmark icon indicating something is good for fine-tuning.
#
# *   Following a given format or tone for the output
# *   Processing the input following specific, complex instructions
# *   Improving latency
# *   Reducing token usage
#
# ## Not good for <Figure id="fg-1"/>
#
# Red cross icon indicating something is not good for fine-tuning.
#
# *   Teaching the model new knowledge
#     *   Use RAG or custom models instead
# *   Performing well at multiple, unrelated tasks
#     *   Do prompt-engineering or create multiple FT models instead
# *   Include up-to-date content in responses
#     *   Use RAG instead
#
# 5
# Page 5:
# ================================================================================
# # Preparing the dataset
#
# ## Example format
#
# ```jsonl
# {
#   "messages": [
#     {
#       "role": "system",
#       "content": "Marv is a factual chatbot
# that is also sarcastic."
#     },
#     {
#       "role": "user",
#       "content": "What's the capital of
# France?"
#     },
#     {
#       "role": "assistant",
#       "content": "Paris, as if everyone
# doesn't know that already."
#     }
#   ]
# }
# ```
#
# -> Take the set of instructions and prompts that you
# found worked best for the model prior to fine-tuning.
# Include them in every training example
#
# -> If you would like to shorten the instructions or
# prompts, it may take more training examples to arrive
# at good results
#
# We recommend using 50-100 examples
# even if the minimum is 10.
#
# <Figure id="fg-0"/>
#
# OpenAI logo with text 'OpenAI 6'
# Page 6:
# ================================================================================
# # Best practices
#
# <Figure id="fg-0"/>
#
# Title graphic for 'Best practices'.
#
# ## Curate examples carefully
#
# Datasets can be difficult to build, start small and invest intentionally. Optimize for fewer high-quality training examples.
#
# *   Consider "prompt baking", or using a basic prompt to generate your initial examples
# *   If your conversations are multi-turn, ensure your examples are representative
# *   Collect examples to target issues detected in evaluation
# *   Consider the balance & diversity of data
# *   Make sure your examples contain all the information needed in the response
#
# ## Automate your feedback pipeline
#
# Introduce automated evaluations to highlight potential problem cases to clean up and use as training data.
#
# Consider the G-Eval approach of using GPT-4 to perform automated testing using a scorecard.
#
# ## Iterate on hyperparameters
#
# Start with the defaults and adjust based on performance.
#
# *   If the model does not appear to converge, increase the learning rate multiplier
# *   If the model does not follow the training data as much as expected increase the number of epochs
# *   If the model becomes less diverse than expected decrease the # of epochs by 1-2
#
# ## Establish a baseline
#
# Often users start with a zero-shot or few-shot prompt to build a baseline evaluation before graduating to fine-tuning.
#
# ## Optimize for latency and token efficiency
#
# When using GPT-4, once you have a baseline evaluation and training examples consider fine-tuning 3.5 to get similar performance for less cost and latency.
#
# Experiment with reducing or removing system instructions with subsequent fine-tuned model versions.
# Page 7:
# ================================================================================
# # Hyperparameters
#
# ## Epochs
#
# Refers to 1 full cycle through the training dataset
#
# If you have hundreds of thousands of examples, we would recommend experimenting with two epochs (or one) to avoid overfitting.
#
# default: auto (standard is 4)
#
# ## Batch size
#
# Number of training examples used to train a single forward & backward pass
# In general, we've found that larger batch sizes tend to work better for larger datasets
#
# default: ~0.2% x N* (max 256)
#
# *N = number of training examples
#
# ## Learning rate multiplier
#
# Scaling factor for the original learning rate
#
# We recommend experimenting with values between 0.02-0.2. We've found that larger learning rates often perform better with larger batch sizes.
#
# default: 0.05, 0.1 or 0.2*
#
# *depends on final batch size
#
# 8

# %% [markdown]
# ## Best Practices & Troubleshooting
#
# ### Response Handling
# - Use `markdown_content` for the fully rendered version with tables and figures in place
# - The `content` field contains raw markdown with `<Table>` and `<Figure>` placeholders that reference the structured data
# - For complex documents, use `detail="hi"` in the config to improve extraction accuracy
# - Always check `prediction.status` before accessing results
# - Handle missing tables/figures with `if page['tables']` checks
#
# ### Error Handling
# ```python
# try:
#     prediction = client.document.generate(
#         domain="document.markdown",
#         url=PRESENTATION_URL
#     )
#
#     prediction = client.predictions.wait(prediction.id)
#
#     if prediction.status == "completed":
#         result = prediction.response
#         # Process and display results
#     else:
#         print(f"Error: Processing failed with status {prediction.status}")
#
# except Exception as e:
#     print(f"Error: {str(e)}")
# ```
#
# ### Performance Optimization
# - Use batch mode for large documents
# - Implement proper timeouts
# - Cache results when processing the same document multiple times
# - Use appropriate detail levels based on document complexity
